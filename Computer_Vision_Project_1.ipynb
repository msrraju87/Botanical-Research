# %% [markdown]
# University X is currently undergoing some research involving understanding the characteristics of
# plant and plant seedlings at various stages of growth. They already have have invested on curating sample
# images. They require an automation which can create a classifier capable of determining a plant's species from a
# photo

# %% [markdown]
# # We will fit Supervised Machine Learning, NN's and CNN's

# %% [markdown]
# Let's first import the relevant libraries

# %%
import os        
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import random
random.seed(0)

# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# We will now read the input using ImageDataGenerator

# %% [markdown]
# # Import the data

# %% [markdown]
# Let's import the input data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !unzip -u "/content/drive/My Drive/Computer Vision/train.zip" -d "/content/drive/My Drive/Computer Vision/train"
# Out:
# Archive:  /content/drive/My Drive/Computer Vision/train.zip

# %%
datagen = ImageDataGenerator(rescale=1./255)

# %%
data = datagen.flow_from_directory('/content/drive/My Drive/Computer Vision/train',target_size=(64,64),batch_size=4750,class_mode='categorical',subset="training")
# Out:
# Found 4750 images belonging to 12 classes.

# %%
X,y = next(data)

# %% [markdown]
# # Dimensions of the data

# %% [markdown]
# Let's now look at the dimensions of the data

# %%
X.shape
# Out:
# (4750, 64, 64, 3)

# %% [markdown]
# We have 4750 inputs of dimensions 64*64 and 3 channels

# %%
y.shape
# Out:
# (4750, 12)

# %% [markdown]
# We have 4750 ouput values and 12 columns as there are 12 categories

# %% [markdown]
# # Let's visualize some of the images

# %%
photos = X[0:25]

# %%
fig,axes = plt.subplots(5,5,figsize=(10,10))

for i in range(25):
  ax = axes[i//5,i%5]
  ax.imshow(photos[i],cmap='gray')
plt.show()

# %% [markdown]
# Let's now look at another set of 25 plants

# %%
photos = X[4000:4025]

# %%
fig,axes = plt.subplots(5,5,figsize=(10,10))

for i in range(25):
  ax = axes[i//5,i%5]
  ax.imshow(photos[i],cmap='gray')
plt.show()

# %% [markdown]
# We will now build models on this data to be able to correctly classify what plant each of them is

# %% [markdown]
# Let's now design, train, tune and test the best AIML image classifier model using:
# - Supervised learning algorithms
# - Neural networks
# - CNN

# %% [markdown]
# # Supervised Machine Learning

# %% [markdown]
# We will train a series of supervised machine learning algorithms to correctly be able to predict the species of each plant

# %% [markdown]
# We will now reshape the data so that we can apply supervised learning algorithms. The columns should equal the product of height, width and number of channels. We are in effect flattening the data

# %%
X_change = X.reshape(4750,12288)

# %%
y_change = np.argmax(y,axis=1)

# %% [markdown]
# Let's split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_change, y_change, test_size=0.33, random_state=42)

# %% [markdown]
# We will now apply a series of supervised learning algorithms. We will calculate the accuracy of each of them and finally pick the alogirthm that gives the best accuracy score

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(lr.score(X_train,y_train))
print(lr.score(X_test,y_test))
# Out:
# 0.9044626021370208
# 0.47767857142857145

# %% [markdown]
# Naive Baye's

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()

# %%
mnb.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print(mnb.score(X_train,y_train))
print(mnb.score(X_test,y_test))
# Out:
# 0.39126335637963544
# 0.2927295918367347

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(svc.score(X_train,y_train))
print(svc.score(X_test,y_test))
# Out:
# 0.8359522313010685
# 0.48341836734693877

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc = DecisionTreeClassifier()

# %%
dc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
print(dc.score(X_train,y_train))
print(dc.score(X_test,y_test))
# Out:
# 1.0
# 0.2576530612244898

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rc = RandomForestClassifier()

# %%
rc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(rc.score(X_train,y_train))
print(rc.score(X_test,y_test))
# Out:
# 1.0
# 0.49362244897959184

# %% [markdown]
# Adaptive Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ac = AdaBoostClassifier()

# %%
ac.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)

# %%
print(ac.score(X_train,y_train))
print(ac.score(X_test,y_test))
# Out:
# 0.2884978001257071
# 0.2889030612244898

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gc = GradientBoostingClassifier()

# %%
gc.fit(X_train,y_train)

# %%
print(gc.score(X_train,y_train))
print(gc.score(X_test,y_test))
# Out:
# 0.9783155248271528
# 0.5255102040816326

# %% [markdown]
# XGBoost

# %%
import xgboost

# %%
xgc = xgboost.XGBClassifier()

# %%
xgc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print(xgc.score(X_train,y_train))
print(xgc.score(X_test,y_test))
# Out:
# 0.9223758642363293
# 0.5522959183673469

# %% [markdown]
# We got the best accuracy for xgboost at around 55%. We could have improved it further by applying performance tuning but since that is not the focus of the current exercise, we will settle at 55.2% as the best accuracy we got from supervised learning. We will next go ahead with building a Neural Network

# %% [markdown]
# # Neural Networks

# %% [markdown]
# Let's build a Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras import regularizers,optimizers

# %% [markdown]
# We will reshape the data here also so that the number of columns will equal the product of height, weight and number of channels

# %%
X_change = X.reshape(4750,12288)

# %% [markdown]
# Here also, we will split the data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_change, y, test_size=0.33, random_state=42)

# %% [markdown]
# We will build a function here, so that we can check the learning rate which provides the best score. We will have 6150 neurons in the hidden layer which is an average of input and output neurons(thumb rule)

# %%
def tune_model(iterations,lr):
  iterations=iterations
  learning_rate = lr
  hidden_nodes = 6150
  output_nodes=12

  model = Sequential()
  model.add(Dense(hidden_nodes,input_shape=(12288,),activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.2))
  model.add(Dense(output_nodes,activation='softmax'))

  adam = optimizers.Adam(learning_rate=learning_rate)

  model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['accuracy'])
  model.fit(X_train,y_train,epochs=iterations,validation_data=(X_test,y_test),batch_size=50)

  score = model.evaluate(X_train,y_train,verbose=0)
  return score

# %% [markdown]
# We will run 10 iterations of 10 epochs each and check the accuracies and the corresponding learning rates

# %%
import math

for k in range(1,11):
  learning_rate = math.pow(10,np.random.uniform(-7,-4))
  tune_model(10,learning_rate)
  print("The learning rate is {}".format(learning_rate))
  print("The end of {} iteration".format(k))
# Out:
# Epoch 1/10
# 64/64 [==============================] - 37s 566ms/step - loss: 2.9623 - accuracy: 0.0933 - val_loss: 2.4835 - val_accuracy: 0.1161
# Epoch 2/10
# 64/64 [==============================] - 36s 559ms/step - loss: 2.6527 - accuracy: 0.1414 - val_loss: 2.4603 - val_accuracy: 0.1244
# Epoch 3/10
# 64/64 [==============================] - 36s 558ms/step - loss: 2.4494 - accuracy: 0.1923 - val_loss: 2.4240 - val_accuracy: 0.1435
# Epoch 4/10
# 64/64 [==============================] - 36s 558ms/step - loss: 2.2908 - accuracy: 0.2420 - val_loss: 2.3633 - val_accuracy: 0.1741
# Epoch 5/10
# 64/64 [==============================] - 36s 561ms/step - loss: 2.1731 - accuracy: 0.2750 - val_loss: 2.3216 - val_accuracy: 0.1805
# Epoch 6/10
# 64/64 [==============================] - 36s 558ms/step - loss: 2.0812 - accuracy: 0.3105 - val_loss: 2.2516 - val_accuracy: 0.2188
# Epoch 7/10
# 64/64 [==============================] - 36s 557ms/step - loss: 1.9801 - accuracy: 0.3400 - val_loss: 2.2117 - val_accuracy: 0.2328
# Epoch 8/10
# 64/64 [==============================] - 36s 559ms/step - loss: 1.8988 - accuracy: 0.3746 - val_loss: 2.1787 - val_accuracy: 0.2455
# Epoch 9/10
# 64/64 [==============================] - 36s 559ms/step - loss: 1.8418 - accuracy: 0.3913 - val_loss: 2.1377 - val_accuracy: 0.2672
# Epoch 10/10
# 64/64 [==============================] - 36s 559ms/step - loss: 1.7648 - accuracy: 0.4195 - val_loss: 2.1025 - val_accuracy: 0.2838
# The learning rate is 6.589375526244079e-07
# The end of 1 iteration
# Epoch 1/10
# 64/64 [==============================] - 37s 569ms/step - loss: 2.4268 - accuracy: 0.3102 - val_loss: 2.6692 - val_accuracy: 0.1352
# Epoch 2/10
# 64/64 [==============================] - 37s 578ms/step - loss: 1.3118 - accuracy: 0.5955 - val_loss: 2.3191 - val_accuracy: 0.1964
# Epoch 3/10
# 64/64 [==============================] - 37s 574ms/step - loss: 0.9870 - accuracy: 0.6930 - val_loss: 3.5162 - val_accuracy: 0.1696
# Epoch 4/10
# 64/64 [==============================] - 37s 575ms/step - loss: 0.7750 - accuracy: 0.7725 - val_loss: 2.6380 - val_accuracy: 0.2117
# Epoch 5/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.5741 - accuracy: 0.8366 - val_loss: 2.3277 - val_accuracy: 0.3112
# Epoch 6/10
# 64/64 [==============================] - 37s 572ms/step - loss: 0.5021 - accuracy: 0.8705 - val_loss: 2.1292 - val_accuracy: 0.3999
# Epoch 7/10
# 64/64 [==============================] - 37s 576ms/step - loss: 0.4229 - accuracy: 0.8887 - val_loss: 5.6221 - val_accuracy: 0.1716
# Epoch 8/10
# 64/64 [==============================] - 37s 574ms/step - loss: 0.3701 - accuracy: 0.9070 - val_loss: 2.8642 - val_accuracy: 0.3227
# Epoch 9/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.3244 - accuracy: 0.9189 - val_loss: 4.8338 - val_accuracy: 0.2334
# Epoch 10/10
# 64/64 [==============================] - 37s 574ms/step - loss: 0.3083 - accuracy: 0.9299 - val_loss: 3.6093 - val_accuracy: 0.2124
# The learning rate is 5.086475348213706e-05
# The end of 2 iteration
# Epoch 1/10
# 64/64 [==============================] - 38s 580ms/step - loss: 3.0355 - accuracy: 0.0874 - val_loss: 2.4849 - val_accuracy: 0.1212
# Epoch 2/10
# 64/64 [==============================] - 37s 572ms/step - loss: 2.8365 - accuracy: 0.1053 - val_loss: 2.4655 - val_accuracy: 0.1256
# Epoch 3/10
# 64/64 [==============================] - 37s 579ms/step - loss: 2.6773 - accuracy: 0.1442 - val_loss: 2.4594 - val_accuracy: 0.1314
# Epoch 4/10
# 64/64 [==============================] - 37s 581ms/step - loss: 2.5700 - accuracy: 0.1615 - val_loss: 2.4581 - val_accuracy: 0.1365
# Epoch 5/10
# 64/64 [==============================] - 37s 575ms/step - loss: 2.4728 - accuracy: 0.1744 - val_loss: 2.4504 - val_accuracy: 0.1505
# Epoch 6/10
# 64/64 [==============================] - 37s 579ms/step - loss: 2.3460 - accuracy: 0.2181 - val_loss: 2.4339 - val_accuracy: 0.1588
# Epoch 7/10
# 64/64 [==============================] - 37s 581ms/step - loss: 2.3004 - accuracy: 0.2344 - val_loss: 2.4048 - val_accuracy: 0.1747
# Epoch 8/10
# 64/64 [==============================] - 37s 579ms/step - loss: 2.2333 - accuracy: 0.2508 - val_loss: 2.3819 - val_accuracy: 0.1913
# Epoch 9/10
# 64/64 [==============================] - 37s 578ms/step - loss: 2.1541 - accuracy: 0.2668 - val_loss: 2.3507 - val_accuracy: 0.2047
# Epoch 10/10
# 64/64 [==============================] - 42s 662ms/step - loss: 2.1021 - accuracy: 0.2957 - val_loss: 2.3304 - val_accuracy: 0.2162
# The learning rate is 3.4968121800382395e-07
# The end of 3 iteration
# Epoch 1/10
# 64/64 [==============================] - 37s 576ms/step - loss: 3.0636 - accuracy: 0.0943 - val_loss: 2.5501 - val_accuracy: 0.0497
# Epoch 2/10
# 64/64 [==============================] - 36s 564ms/step - loss: 3.0169 - accuracy: 0.0905 - val_loss: 2.5291 - val_accuracy: 0.0778
# Epoch 3/10
# 64/64 [==============================] - 36s 565ms/step - loss: 2.9201 - accuracy: 0.1084 - val_loss: 2.5203 - val_accuracy: 0.0938
# Epoch 4/10
# 64/64 [==============================] - 36s 567ms/step - loss: 2.8815 - accuracy: 0.1106 - val_loss: 2.5221 - val_accuracy: 0.1046
# Epoch 5/10
# 64/64 [==============================] - 36s 567ms/step - loss: 2.8153 - accuracy: 0.1282 - val_loss: 2.5322 - val_accuracy: 0.1116
# Epoch 6/10
# 64/64 [==============================] - 36s 570ms/step - loss: 2.7758 - accuracy: 0.1304 - val_loss: 2.5486 - val_accuracy: 0.1180
# Epoch 7/10
# 64/64 [==============================] - 36s 568ms/step - loss: 2.7262 - accuracy: 0.1417 - val_loss: 2.5666 - val_accuracy: 0.1288
# Epoch 8/10
# 64/64 [==============================] - 36s 567ms/step - loss: 2.6702 - accuracy: 0.1527 - val_loss: 2.5855 - val_accuracy: 0.1352
# Epoch 9/10
# 64/64 [==============================] - 36s 566ms/step - loss: 2.6555 - accuracy: 0.1571 - val_loss: 2.5929 - val_accuracy: 0.1429
# Epoch 10/10
# 64/64 [==============================] - 36s 569ms/step - loss: 2.5841 - accuracy: 0.1612 - val_loss: 2.5959 - val_accuracy: 0.1441
# The learning rate is 1.139596124398913e-07
# The end of 4 iteration
# Epoch 1/10
# 64/64 [==============================] - 38s 580ms/step - loss: 2.7948 - accuracy: 0.1191 - val_loss: 2.4842 - val_accuracy: 0.1224
# Epoch 2/10
# 64/64 [==============================] - 37s 579ms/step - loss: 2.2647 - accuracy: 0.2561 - val_loss: 2.4243 - val_accuracy: 0.1582
# Epoch 3/10
# 64/64 [==============================] - 37s 580ms/step - loss: 1.9967 - accuracy: 0.3391 - val_loss: 2.3196 - val_accuracy: 0.1792
# Epoch 4/10
# 64/64 [==============================] - 37s 576ms/step - loss: 1.7956 - accuracy: 0.4180 - val_loss: 2.2007 - val_accuracy: 0.2436
# Epoch 5/10
# 64/64 [==============================] - 37s 574ms/step - loss: 1.6225 - accuracy: 0.4771 - val_loss: 2.1243 - val_accuracy: 0.2749
# Epoch 6/10
# 64/64 [==============================] - 37s 580ms/step - loss: 1.5190 - accuracy: 0.5151 - val_loss: 2.0538 - val_accuracy: 0.2978
# Epoch 7/10
# 64/64 [==============================] - 37s 584ms/step - loss: 1.4116 - accuracy: 0.5528 - val_loss: 1.9283 - val_accuracy: 0.3616
# Epoch 8/10
# 64/64 [==============================] - 37s 574ms/step - loss: 1.3254 - accuracy: 0.5933 - val_loss: 1.8735 - val_accuracy: 0.3801
# Epoch 9/10
# 64/64 [==============================] - 37s 576ms/step - loss: 1.2569 - accuracy: 0.6141 - val_loss: 1.8566 - val_accuracy: 0.3871
# Epoch 10/10
# 64/64 [==============================] - 37s 577ms/step - loss: 1.1831 - accuracy: 0.6455 - val_loss: 1.8324 - val_accuracy: 0.3999
# The learning rate is 1.9038668484853744e-06
# The end of 5 iteration
# Epoch 1/10
# 64/64 [==============================] - 37s 575ms/step - loss: 3.0825 - accuracy: 0.0896 - val_loss: 2.5077 - val_accuracy: 0.0663
# Epoch 2/10
# 64/64 [==============================] - 37s 574ms/step - loss: 2.8750 - accuracy: 0.1135 - val_loss: 2.4790 - val_accuracy: 0.1103
# Epoch 3/10
# 64/64 [==============================] - 37s 574ms/step - loss: 2.7116 - accuracy: 0.1288 - val_loss: 2.4683 - val_accuracy: 0.1154
# Epoch 4/10
# 64/64 [==============================] - 37s 572ms/step - loss: 2.5731 - accuracy: 0.1587 - val_loss: 2.4581 - val_accuracy: 0.1224
# Epoch 5/10
# 64/64 [==============================] - 37s 574ms/step - loss: 2.4673 - accuracy: 0.1876 - val_loss: 2.4522 - val_accuracy: 0.1346
# Epoch 6/10
# 64/64 [==============================] - 39s 619ms/step - loss: 2.4026 - accuracy: 0.2102 - val_loss: 2.4386 - val_accuracy: 0.1594
# Epoch 7/10
# 64/64 [==============================] - 37s 574ms/step - loss: 2.3176 - accuracy: 0.2234 - val_loss: 2.4162 - val_accuracy: 0.1798
# Epoch 8/10
# 64/64 [==============================] - 37s 572ms/step - loss: 2.2634 - accuracy: 0.2445 - val_loss: 2.3910 - val_accuracy: 0.2028
# Epoch 9/10
# 64/64 [==============================] - 37s 572ms/step - loss: 2.1961 - accuracy: 0.2684 - val_loss: 2.3710 - val_accuracy: 0.2207
# Epoch 10/10
# 64/64 [==============================] - 36s 571ms/step - loss: 2.1476 - accuracy: 0.2816 - val_loss: 2.3425 - val_accuracy: 0.2404
# The learning rate is 2.8862259063110093e-07
# The end of 6 iteration
# Epoch 1/10
# 64/64 [==============================] - 37s 573ms/step - loss: 2.4955 - accuracy: 0.2055 - val_loss: 2.4345 - val_accuracy: 0.1460
# Epoch 2/10
# 64/64 [==============================] - 37s 572ms/step - loss: 1.7675 - accuracy: 0.4205 - val_loss: 2.2940 - val_accuracy: 0.1626
# Epoch 3/10
# 64/64 [==============================] - 37s 573ms/step - loss: 1.4448 - accuracy: 0.5349 - val_loss: 2.1851 - val_accuracy: 0.2200
# Epoch 4/10
# 64/64 [==============================] - 37s 574ms/step - loss: 1.2620 - accuracy: 0.5999 - val_loss: 2.0255 - val_accuracy: 0.2978
# Epoch 5/10
# 64/64 [==============================] - 37s 572ms/step - loss: 1.0911 - accuracy: 0.6596 - val_loss: 2.1213 - val_accuracy: 0.2653
# Epoch 6/10
# 64/64 [==============================] - 36s 569ms/step - loss: 0.9649 - accuracy: 0.7181 - val_loss: 1.9401 - val_accuracy: 0.3463
# Epoch 7/10
# 64/64 [==============================] - 37s 574ms/step - loss: 0.8730 - accuracy: 0.7476 - val_loss: 1.8259 - val_accuracy: 0.3673
# Epoch 8/10
# 64/64 [==============================] - 36s 571ms/step - loss: 0.7892 - accuracy: 0.7844 - val_loss: 1.7653 - val_accuracy: 0.3967
# Epoch 9/10
# 64/64 [==============================] - 36s 571ms/step - loss: 0.7204 - accuracy: 0.8070 - val_loss: 1.8916 - val_accuracy: 0.4152
# Epoch 10/10
# 64/64 [==============================] - 37s 573ms/step - loss: 0.6518 - accuracy: 0.8344 - val_loss: 1.9546 - val_accuracy: 0.3795
# The learning rate is 5.98745153579907e-06
# The end of 7 iteration
# Epoch 1/10
# 64/64 [==============================] - 37s 575ms/step - loss: 2.3392 - accuracy: 0.2577 - val_loss: 2.3141 - val_accuracy: 0.2188
# Epoch 2/10
# 64/64 [==============================] - 36s 570ms/step - loss: 1.4908 - accuracy: 0.5107 - val_loss: 2.2526 - val_accuracy: 0.2347
# Epoch 3/10
# 64/64 [==============================] - 36s 567ms/step - loss: 1.1803 - accuracy: 0.6248 - val_loss: 2.1055 - val_accuracy: 0.2315
# Epoch 4/10
# 64/64 [==============================] - 36s 569ms/step - loss: 0.9751 - accuracy: 0.7014 - val_loss: 2.3246 - val_accuracy: 0.2162
# Epoch 5/10
# 64/64 [==============================] - 36s 568ms/step - loss: 0.8271 - accuracy: 0.7640 - val_loss: 2.2438 - val_accuracy: 0.2436
# Epoch 6/10
# 64/64 [==============================] - 36s 570ms/step - loss: 0.7063 - accuracy: 0.8140 - val_loss: 2.0572 - val_accuracy: 0.3871
# Epoch 7/10
# 64/64 [==============================] - 36s 569ms/step - loss: 0.6234 - accuracy: 0.8394 - val_loss: 2.2094 - val_accuracy: 0.2895
# Epoch 8/10
# 64/64 [==============================] - 36s 569ms/step - loss: 0.5491 - accuracy: 0.8661 - val_loss: 1.8482 - val_accuracy: 0.4037
# Epoch 9/10
# 64/64 [==============================] - 36s 568ms/step - loss: 0.4688 - accuracy: 0.8919 - val_loss: 2.1533 - val_accuracy: 0.4337
# Epoch 10/10
# 64/64 [==============================] - 36s 569ms/step - loss: 0.4401 - accuracy: 0.8957 - val_loss: 2.4119 - val_accuracy: 0.3527
# The learning rate is 1.4869516225561744e-05
# The end of 8 iteration
# Epoch 1/10
# 64/64 [==============================] - 39s 599ms/step - loss: 2.3819 - accuracy: 0.2542 - val_loss: 2.3825 - val_accuracy: 0.1518
# Epoch 2/10
# 64/64 [==============================] - 38s 599ms/step - loss: 1.5680 - accuracy: 0.4777 - val_loss: 2.3362 - val_accuracy: 0.1403
# Epoch 3/10
# 64/64 [==============================] - 38s 594ms/step - loss: 1.2602 - accuracy: 0.5842 - val_loss: 2.0737 - val_accuracy: 0.3093
# Epoch 4/10
# 64/64 [==============================] - 38s 592ms/step - loss: 1.0293 - accuracy: 0.6713 - val_loss: 2.0422 - val_accuracy: 0.3253
# Epoch 5/10
# 64/64 [==============================] - 38s 601ms/step - loss: 0.8949 - accuracy: 0.7351 - val_loss: 2.0703 - val_accuracy: 0.3323
# Epoch 6/10
# 64/64 [==============================] - 38s 601ms/step - loss: 0.7781 - accuracy: 0.7822 - val_loss: 1.8605 - val_accuracy: 0.3776
# Epoch 7/10
# 64/64 [==============================] - 38s 599ms/step - loss: 0.6829 - accuracy: 0.8140 - val_loss: 2.9308 - val_accuracy: 0.2526
# Epoch 8/10
# 64/64 [==============================] - 38s 597ms/step - loss: 0.5866 - accuracy: 0.8492 - val_loss: 2.2876 - val_accuracy: 0.3259
# Epoch 9/10
# 64/64 [==============================] - 38s 595ms/step - loss: 0.5209 - accuracy: 0.8809 - val_loss: 1.9616 - val_accuracy: 0.3380
# Epoch 10/10
# 64/64 [==============================] - 38s 603ms/step - loss: 0.4653 - accuracy: 0.8953 - val_loss: 2.1980 - val_accuracy: 0.3622
# The learning rate is 1.2369677326780132e-05
# The end of 9 iteration
# Epoch 1/10
# 64/64 [==============================] - 40s 609ms/step - loss: 2.4685 - accuracy: 0.3328 - val_loss: 2.9168 - val_accuracy: 0.1862
# Epoch 2/10
# 64/64 [==============================] - 38s 589ms/step - loss: 1.2934 - accuracy: 0.6031 - val_loss: 2.4480 - val_accuracy: 0.1416
# Epoch 3/10
# 64/64 [==============================] - 38s 594ms/step - loss: 0.9429 - accuracy: 0.7209 - val_loss: 2.4441 - val_accuracy: 0.2500
# Epoch 4/10
# 64/64 [==============================] - 37s 587ms/step - loss: 0.7223 - accuracy: 0.7894 - val_loss: 5.4123 - val_accuracy: 0.1435
# Epoch 5/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.6126 - accuracy: 0.8240 - val_loss: 3.3018 - val_accuracy: 0.2251
# Epoch 6/10
# 64/64 [==============================] - 37s 576ms/step - loss: 0.5202 - accuracy: 0.8564 - val_loss: 2.6786 - val_accuracy: 0.3138
# Epoch 7/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.4052 - accuracy: 0.8922 - val_loss: 4.5473 - val_accuracy: 0.2194
# Epoch 8/10
# 64/64 [==============================] - 37s 576ms/step - loss: 0.3393 - accuracy: 0.9117 - val_loss: 3.9806 - val_accuracy: 0.2519
# Epoch 9/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.3395 - accuracy: 0.9158 - val_loss: 3.9833 - val_accuracy: 0.2411
# Epoch 10/10
# 64/64 [==============================] - 37s 578ms/step - loss: 0.2838 - accuracy: 0.9302 - val_loss: 3.4651 - val_accuracy: 0.3157
# The learning rate is 7.731233701704274e-05
# The end of 10 iteration

# %% [markdown]
# We are getting the highest validation accuracy at a learning rate of 1.9038668484853744e-06

# %% [markdown]
# We will now define a callback for early stopping

# %%
import tensorflow
callback = tensorflow.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4, min_delta=0.01)

# %% [markdown]
# We will now run the model at the learning rate we found above

# %%
iterations=30
learning_rate = 1.9038668484853744e-06
hidden_nodes = 6150
output_nodes=12

model = Sequential()
model.add(Dense(hidden_nodes,input_shape=(12288,),activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(output_nodes,activation='softmax'))

adam = optimizers.Adam(learning_rate=learning_rate)

model.compile(loss='categorical_crossentropy',optimizer=adam,metrics=['accuracy'])
model.fit(X_train,y_train,epochs=iterations,validation_data=(X_test,y_test),batch_size=50,callbacks=[callback])
# Out:
# Epoch 1/30
# 64/64 [==============================] - 37s 568ms/step - loss: 2.7888 - accuracy: 0.1172 - val_loss: 2.4584 - val_accuracy: 0.1416
# Epoch 2/30
# 64/64 [==============================] - 36s 569ms/step - loss: 2.2601 - accuracy: 0.2454 - val_loss: 2.3696 - val_accuracy: 0.1741
# Epoch 3/30
# 64/64 [==============================] - 39s 611ms/step - loss: 1.9885 - accuracy: 0.3356 - val_loss: 2.3092 - val_accuracy: 0.1645
# Epoch 4/30
# 64/64 [==============================] - 36s 569ms/step - loss: 1.8020 - accuracy: 0.3982 - val_loss: 2.1753 - val_accuracy: 0.2640
# Epoch 5/30
# 64/64 [==============================] - 36s 569ms/step - loss: 1.6334 - accuracy: 0.4708 - val_loss: 2.1071 - val_accuracy: 0.2819
# Epoch 6/30
# 64/64 [==============================] - 36s 571ms/step - loss: 1.5185 - accuracy: 0.5176 - val_loss: 2.0233 - val_accuracy: 0.3061
# Epoch 7/30
# 64/64 [==============================] - 37s 572ms/step - loss: 1.4199 - accuracy: 0.5459 - val_loss: 1.9478 - val_accuracy: 0.3374
# Epoch 8/30
# 64/64 [==============================] - 37s 575ms/step - loss: 1.3145 - accuracy: 0.5999 - val_loss: 1.8898 - val_accuracy: 0.3737
# Epoch 9/30
# 64/64 [==============================] - 37s 573ms/step - loss: 1.2357 - accuracy: 0.6395 - val_loss: 1.8382 - val_accuracy: 0.3999
# Epoch 10/30
# 64/64 [==============================] - 37s 574ms/step - loss: 1.1836 - accuracy: 0.6468 - val_loss: 1.8264 - val_accuracy: 0.3986
# Epoch 11/30
# 64/64 [==============================] - 37s 574ms/step - loss: 1.1187 - accuracy: 0.6725 - val_loss: 1.7710 - val_accuracy: 0.4241
# Epoch 12/30
# 64/64 [==============================] - 36s 571ms/step - loss: 1.0593 - accuracy: 0.7096 - val_loss: 1.7930 - val_accuracy: 0.4145
# Epoch 13/30
# 64/64 [==============================] - 37s 574ms/step - loss: 1.0040 - accuracy: 0.7222 - val_loss: 1.7745 - val_accuracy: 0.4228
# Epoch 14/30
# 64/64 [==============================] - 37s 575ms/step - loss: 0.9564 - accuracy: 0.7307 - val_loss: 1.7370 - val_accuracy: 0.4337
# Epoch 15/30
# 64/64 [==============================] - 37s 578ms/step - loss: 0.9151 - accuracy: 0.7577 - val_loss: 1.7156 - val_accuracy: 0.4394
# Epoch 16/30
# 64/64 [==============================] - 37s 578ms/step - loss: 0.8720 - accuracy: 0.7722 - val_loss: 1.7348 - val_accuracy: 0.4349
# Epoch 17/30
# 64/64 [==============================] - 37s 574ms/step - loss: 0.8405 - accuracy: 0.7762 - val_loss: 1.7353 - val_accuracy: 0.4394
# Epoch 18/30
# 64/64 [==============================] - 37s 573ms/step - loss: 0.8005 - accuracy: 0.8004 - val_loss: 1.6864 - val_accuracy: 0.4452
# Epoch 19/30
# 64/64 [==============================] - 37s 573ms/step - loss: 0.7653 - accuracy: 0.8146 - val_loss: 1.7257 - val_accuracy: 0.4522
# Epoch 20/30
# 64/64 [==============================] - 37s 573ms/step - loss: 0.7489 - accuracy: 0.8136 - val_loss: 1.6728 - val_accuracy: 0.4547
# Epoch 21/30
# 64/64 [==============================] - 37s 576ms/step - loss: 0.7063 - accuracy: 0.8294 - val_loss: 1.6802 - val_accuracy: 0.4509
# Epoch 22/30
# 64/64 [==============================] - 37s 574ms/step - loss: 0.6713 - accuracy: 0.8507 - val_loss: 1.7188 - val_accuracy: 0.4324
# Epoch 23/30
# 64/64 [==============================] - 37s 576ms/step - loss: 0.6535 - accuracy: 0.8554 - val_loss: 1.7159 - val_accuracy: 0.4464

# %% [markdown]
# We have an accuracy of around 45% which is lower than what we got from xgboost. We will next use CNN's and see how the performance will change

# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# Let's build a CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization,Conv2D,MaxPooling2D
from tensorflow.keras import regularizers,optimizers

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# We will create 3 convolutions of size 8, 16 and 32 and then create an FC with 128 neurons in the hidden layer and 12 neurons in the output layer

# %%
def model_cnn(n,lr):

  epochs = n

  lr = lr


  model = Sequential()

  model.add(Conv2D(filters=8,kernel_size=3,activation='relu',input_shape=(64,64,3)))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(BatchNormalization())
  #model.add(Dropout(0.2))
  model.add(Conv2D(filters=16,kernel_size=3,activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(BatchNormalization())
  #model.add(Dropout(0.2))
  model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))

  model.add(Flatten())
  model.add(Dense(128,activation='relu'))
  model.add(Dense(12,activation='softmax'))

  optimizer = optimizers.Adam(learning_rate = lr)

  model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

  model.fit(x=X_train, y=y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))

# %% [markdown]
# We will run 10 iterations of 10 epochs each and check the accuracies and the corresponding learning rates

# %%
import math

for k in range(1,21):
  learning_rate = math.pow(10,np.random.uniform(-7,-4))
  model_cnn(10,learning_rate)
  print("The learning rate is {}".format(learning_rate))
  print("The end of {} iteration".format(k))
# Out:
# Epoch 1/10
# 100/100 [==============================] - 10s 90ms/step - loss: 2.7425 - accuracy: 0.0789 - val_loss: 2.5167 - val_accuracy: 0.0523
# Epoch 2/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6618 - accuracy: 0.0867 - val_loss: 2.5293 - val_accuracy: 0.1078
# Epoch 3/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5991 - accuracy: 0.0955 - val_loss: 2.5157 - val_accuracy: 0.1084
# Epoch 4/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5542 - accuracy: 0.1128 - val_loss: 2.4897 - val_accuracy: 0.1071
# Epoch 5/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5207 - accuracy: 0.1131 - val_loss: 2.4717 - val_accuracy: 0.1180
# Epoch 6/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4908 - accuracy: 0.1257 - val_loss: 2.4628 - val_accuracy: 0.1314
# Epoch 7/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4660 - accuracy: 0.1323 - val_loss: 2.4574 - val_accuracy: 0.1448
# Epoch 8/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4447 - accuracy: 0.1433 - val_loss: 2.4487 - val_accuracy: 0.1575
# Epoch 9/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4292 - accuracy: 0.1474 - val_loss: 2.4388 - val_accuracy: 0.1703
# Epoch 10/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.4104 - accuracy: 0.1581 - val_loss: 2.4283 - val_accuracy: 0.1747
# The learning rate is 1.1974031133048638e-06
# The end of 1 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 90ms/step - loss: 2.3537 - accuracy: 0.1961 - val_loss: 2.4410 - val_accuracy: 0.1422
# Epoch 2/10
# 100/100 [==============================] - 9s 88ms/step - loss: 1.9419 - accuracy: 0.3774 - val_loss: 2.5271 - val_accuracy: 0.1467
# Epoch 3/10
# 100/100 [==============================] - 9s 87ms/step - loss: 1.6172 - accuracy: 0.4805 - val_loss: 2.6572 - val_accuracy: 0.1543
# Epoch 4/10
# 100/100 [==============================] - 9s 88ms/step - loss: 1.3581 - accuracy: 0.5745 - val_loss: 2.5456 - val_accuracy: 0.1952
# Epoch 5/10
# 100/100 [==============================] - 9s 88ms/step - loss: 1.1739 - accuracy: 0.6248 - val_loss: 1.8846 - val_accuracy: 0.3061
# Epoch 6/10
# 100/100 [==============================] - 9s 87ms/step - loss: 1.0247 - accuracy: 0.6851 - val_loss: 1.4960 - val_accuracy: 0.4764
# Epoch 7/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.9117 - accuracy: 0.7238 - val_loss: 1.2984 - val_accuracy: 0.5606
# Epoch 8/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.8045 - accuracy: 0.7637 - val_loss: 1.1442 - val_accuracy: 0.6135
# Epoch 9/10
# 100/100 [==============================] - 9s 87ms/step - loss: 0.7167 - accuracy: 0.7979 - val_loss: 1.0962 - val_accuracy: 0.6333
# Epoch 10/10
# 100/100 [==============================] - 9s 87ms/step - loss: 0.6581 - accuracy: 0.8193 - val_loss: 1.0464 - val_accuracy: 0.6569
# The learning rate is 3.579649551050552e-05
# The end of 2 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 90ms/step - loss: 2.3058 - accuracy: 0.1983 - val_loss: 2.4554 - val_accuracy: 0.1269
# Epoch 2/10
# 100/100 [==============================] - 9s 88ms/step - loss: 1.7751 - accuracy: 0.4224 - val_loss: 2.5574 - val_accuracy: 0.1741
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.2280 - accuracy: 0.6078 - val_loss: 2.5048 - val_accuracy: 0.2360
# Epoch 4/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.8891 - accuracy: 0.7212 - val_loss: 2.1685 - val_accuracy: 0.2851
# Epoch 5/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.6794 - accuracy: 0.8008 - val_loss: 1.5918 - val_accuracy: 0.4541
# Epoch 6/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.5507 - accuracy: 0.8476 - val_loss: 1.2163 - val_accuracy: 0.5912
# Epoch 7/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.4423 - accuracy: 0.8938 - val_loss: 1.0008 - val_accuracy: 0.6652
# Epoch 8/10
# 100/100 [==============================] - 9s 89ms/step - loss: 0.3552 - accuracy: 0.9192 - val_loss: 0.9646 - val_accuracy: 0.6754
# Epoch 9/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.2825 - accuracy: 0.9437 - val_loss: 0.9412 - val_accuracy: 0.7009
# Epoch 10/10
# 100/100 [==============================] - 9s 87ms/step - loss: 0.2335 - accuracy: 0.9617 - val_loss: 0.9555 - val_accuracy: 0.6913
# The learning rate is 9.092371837156582e-05
# The end of 3 iteration
# Epoch 1/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6647 - accuracy: 0.1018 - val_loss: 2.4967 - val_accuracy: 0.0599
# Epoch 2/10
# 100/100 [==============================] - 9s 87ms/step - loss: 2.6505 - accuracy: 0.1009 - val_loss: 2.5125 - val_accuracy: 0.0702
# Epoch 3/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6428 - accuracy: 0.1050 - val_loss: 2.5281 - val_accuracy: 0.0759
# Epoch 4/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6303 - accuracy: 0.1072 - val_loss: 2.5361 - val_accuracy: 0.0784
# Epoch 5/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6181 - accuracy: 0.1138 - val_loss: 2.5366 - val_accuracy: 0.0950
# Epoch 6/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6116 - accuracy: 0.1103 - val_loss: 2.5437 - val_accuracy: 0.0912
# Epoch 7/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.6034 - accuracy: 0.1160 - val_loss: 2.5606 - val_accuracy: 0.1097
# Epoch 8/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5934 - accuracy: 0.1141 - val_loss: 2.5758 - val_accuracy: 0.1148
# Epoch 9/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5851 - accuracy: 0.1160 - val_loss: 2.5809 - val_accuracy: 0.1193
# Epoch 10/10
# 100/100 [==============================] - 9s 88ms/step - loss: 2.5791 - accuracy: 0.1210 - val_loss: 2.5797 - val_accuracy: 0.1205
# The learning rate is 2.2419943428439745e-07
# The end of 4 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 91ms/step - loss: 2.3697 - accuracy: 0.1873 - val_loss: 2.4138 - val_accuracy: 0.1429
# Epoch 2/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.0311 - accuracy: 0.3363 - val_loss: 2.5280 - val_accuracy: 0.1358
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.7544 - accuracy: 0.4346 - val_loss: 2.5881 - val_accuracy: 0.1486
# Epoch 4/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.5072 - accuracy: 0.5223 - val_loss: 2.2294 - val_accuracy: 0.2047
# Epoch 5/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3072 - accuracy: 0.5924 - val_loss: 1.7104 - val_accuracy: 0.4254
# Epoch 6/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1571 - accuracy: 0.6439 - val_loss: 1.4294 - val_accuracy: 0.5179
# Epoch 7/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0189 - accuracy: 0.6964 - val_loss: 1.3195 - val_accuracy: 0.5478
# Epoch 8/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.9137 - accuracy: 0.7329 - val_loss: 1.2320 - val_accuracy: 0.5759
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 0.8189 - accuracy: 0.7649 - val_loss: 1.1887 - val_accuracy: 0.5925
# Epoch 10/10
# 100/100 [==============================] - 9s 89ms/step - loss: 0.7462 - accuracy: 0.7929 - val_loss: 1.1486 - val_accuracy: 0.6078
# The learning rate is 3.3531542966490265e-05
# The end of 5 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 90ms/step - loss: 2.7486 - accuracy: 0.0918 - val_loss: 2.4920 - val_accuracy: 0.0810
# Epoch 2/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.6560 - accuracy: 0.0921 - val_loss: 2.5006 - val_accuracy: 0.0893
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.5924 - accuracy: 0.0990 - val_loss: 2.4945 - val_accuracy: 0.1084
# Epoch 4/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.5463 - accuracy: 0.1069 - val_loss: 2.4841 - val_accuracy: 0.1237
# Epoch 5/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.5102 - accuracy: 0.1163 - val_loss: 2.4773 - val_accuracy: 0.1276
# Epoch 6/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4813 - accuracy: 0.1270 - val_loss: 2.4707 - val_accuracy: 0.1237
# Epoch 7/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4586 - accuracy: 0.1348 - val_loss: 2.4627 - val_accuracy: 0.1307
# Epoch 8/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4382 - accuracy: 0.1427 - val_loss: 2.4517 - val_accuracy: 0.1384
# Epoch 9/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4227 - accuracy: 0.1446 - val_loss: 2.4406 - val_accuracy: 0.1480
# Epoch 10/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4086 - accuracy: 0.1521 - val_loss: 2.4298 - val_accuracy: 0.1499
# The learning rate is 9.087928002777688e-07
# The end of 6 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 91ms/step - loss: 2.4803 - accuracy: 0.1320 - val_loss: 2.4497 - val_accuracy: 0.1365
# Epoch 2/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2894 - accuracy: 0.2146 - val_loss: 2.4253 - val_accuracy: 0.1384
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.1493 - accuracy: 0.2816 - val_loss: 2.4391 - val_accuracy: 0.1448
# Epoch 4/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.0108 - accuracy: 0.3416 - val_loss: 2.3641 - val_accuracy: 0.1767
# Epoch 5/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.8656 - accuracy: 0.4048 - val_loss: 2.1566 - val_accuracy: 0.2487
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.7218 - accuracy: 0.4525 - val_loss: 1.9066 - val_accuracy: 0.3514
# Epoch 7/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.5916 - accuracy: 0.4943 - val_loss: 1.7661 - val_accuracy: 0.4126
# Epoch 8/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.4662 - accuracy: 0.5346 - val_loss: 1.6764 - val_accuracy: 0.4407
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3480 - accuracy: 0.5710 - val_loss: 1.6082 - val_accuracy: 0.4598
# Epoch 10/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.2541 - accuracy: 0.6078 - val_loss: 1.5294 - val_accuracy: 0.4860
# The learning rate is 1.6339162988466752e-05
# The end of 7 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 90ms/step - loss: 2.4382 - accuracy: 0.1644 - val_loss: 2.4496 - val_accuracy: 0.1276
# Epoch 2/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.1375 - accuracy: 0.2920 - val_loss: 2.4538 - val_accuracy: 0.1365
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.8984 - accuracy: 0.3891 - val_loss: 2.3970 - val_accuracy: 0.1671
# Epoch 4/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.6965 - accuracy: 0.4519 - val_loss: 2.1782 - val_accuracy: 0.2487
# Epoch 5/10
# 100/100 [==============================] - 9s 88ms/step - loss: 1.5317 - accuracy: 0.5050 - val_loss: 1.8370 - val_accuracy: 0.3916
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.3898 - accuracy: 0.5550 - val_loss: 1.6164 - val_accuracy: 0.4611
# Epoch 7/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.2878 - accuracy: 0.5955 - val_loss: 1.5048 - val_accuracy: 0.5038
# Epoch 8/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1986 - accuracy: 0.6232 - val_loss: 1.4391 - val_accuracy: 0.5096
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.1166 - accuracy: 0.6480 - val_loss: 1.3978 - val_accuracy: 0.5293
# Epoch 10/10
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0406 - accuracy: 0.6760 - val_loss: 1.3486 - val_accuracy: 0.5453
# The learning rate is 2.1042977977905808e-05
# The end of 8 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 92ms/step - loss: 2.6312 - accuracy: 0.0984 - val_loss: 2.4696 - val_accuracy: 0.1205
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5600 - accuracy: 0.1091 - val_loss: 2.4648 - val_accuracy: 0.1199
# Epoch 3/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.5110 - accuracy: 0.1301 - val_loss: 2.4519 - val_accuracy: 0.1224
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4701 - accuracy: 0.1395 - val_loss: 2.4339 - val_accuracy: 0.1295
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4337 - accuracy: 0.1508 - val_loss: 2.4182 - val_accuracy: 0.1460
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4057 - accuracy: 0.1644 - val_loss: 2.4074 - val_accuracy: 0.1582
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3780 - accuracy: 0.1810 - val_loss: 2.3962 - val_accuracy: 0.1709
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3551 - accuracy: 0.1917 - val_loss: 2.3814 - val_accuracy: 0.1907
# Epoch 9/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3361 - accuracy: 0.1999 - val_loss: 2.3652 - val_accuracy: 0.1996
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3135 - accuracy: 0.2137 - val_loss: 2.3483 - val_accuracy: 0.2130
# The learning rate is 1.352852898729304e-06
# The end of 9 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 91ms/step - loss: 2.6381 - accuracy: 0.0940 - val_loss: 2.4699 - val_accuracy: 0.1071
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5329 - accuracy: 0.1229 - val_loss: 2.4445 - val_accuracy: 0.1040
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4628 - accuracy: 0.1474 - val_loss: 2.4228 - val_accuracy: 0.1365
# Epoch 4/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4163 - accuracy: 0.1735 - val_loss: 2.4013 - val_accuracy: 0.1486
# Epoch 5/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.3771 - accuracy: 0.1842 - val_loss: 2.3751 - val_accuracy: 0.1671
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3433 - accuracy: 0.1992 - val_loss: 2.3539 - val_accuracy: 0.1945
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3152 - accuracy: 0.2131 - val_loss: 2.3381 - val_accuracy: 0.2130
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.2902 - accuracy: 0.2244 - val_loss: 2.3218 - val_accuracy: 0.2207
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2640 - accuracy: 0.2332 - val_loss: 2.3051 - val_accuracy: 0.2245
# Epoch 10/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2385 - accuracy: 0.2470 - val_loss: 2.2867 - val_accuracy: 0.2334
# The learning rate is 1.72787338478633e-06
# The end of 10 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 93ms/step - loss: 2.3997 - accuracy: 0.1669 - val_loss: 2.4628 - val_accuracy: 0.1148
# Epoch 2/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.1423 - accuracy: 0.2800 - val_loss: 2.6351 - val_accuracy: 0.1429
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.8713 - accuracy: 0.4023 - val_loss: 2.7436 - val_accuracy: 0.1397
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.5530 - accuracy: 0.5185 - val_loss: 2.5318 - val_accuracy: 0.1945
# Epoch 5/10
# 100/100 [==============================] - 9s 91ms/step - loss: 1.2826 - accuracy: 0.6075 - val_loss: 1.8933 - val_accuracy: 0.3380
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.0805 - accuracy: 0.6722 - val_loss: 1.5639 - val_accuracy: 0.4624
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.9346 - accuracy: 0.7348 - val_loss: 1.3985 - val_accuracy: 0.5159
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.8208 - accuracy: 0.7693 - val_loss: 1.2477 - val_accuracy: 0.5753
# Epoch 9/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.7256 - accuracy: 0.8121 - val_loss: 1.1873 - val_accuracy: 0.5906
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.6402 - accuracy: 0.8360 - val_loss: 1.1507 - val_accuracy: 0.6110
# The learning rate is 3.913910457362216e-05
# The end of 11 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 92ms/step - loss: 2.7549 - accuracy: 0.0597 - val_loss: 2.5262 - val_accuracy: 0.0568
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.7372 - accuracy: 0.0616 - val_loss: 2.5523 - val_accuracy: 0.0670
# Epoch 3/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.7180 - accuracy: 0.0673 - val_loss: 2.5721 - val_accuracy: 0.0714
# Epoch 4/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.7016 - accuracy: 0.0657 - val_loss: 2.5883 - val_accuracy: 0.0695
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6858 - accuracy: 0.0704 - val_loss: 2.6064 - val_accuracy: 0.0714
# Epoch 6/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6714 - accuracy: 0.0745 - val_loss: 2.6243 - val_accuracy: 0.0810
# Epoch 7/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6578 - accuracy: 0.0717 - val_loss: 2.6358 - val_accuracy: 0.0823
# Epoch 8/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6433 - accuracy: 0.0779 - val_loss: 2.6385 - val_accuracy: 0.0861
# Epoch 9/10
# 100/100 [==============================] - 9s 92ms/step - loss: 2.6356 - accuracy: 0.0795 - val_loss: 2.6338 - val_accuracy: 0.0880
# Epoch 10/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6187 - accuracy: 0.0849 - val_loss: 2.6257 - val_accuracy: 0.0880
# The learning rate is 3.03024577520275e-07
# The end of 12 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 93ms/step - loss: 2.6454 - accuracy: 0.1354 - val_loss: 2.4854 - val_accuracy: 0.1129
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6216 - accuracy: 0.1395 - val_loss: 2.4937 - val_accuracy: 0.0880
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5956 - accuracy: 0.1380 - val_loss: 2.4977 - val_accuracy: 0.0886
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5786 - accuracy: 0.1342 - val_loss: 2.5069 - val_accuracy: 0.1059
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5590 - accuracy: 0.1392 - val_loss: 2.5195 - val_accuracy: 0.1244
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5421 - accuracy: 0.1414 - val_loss: 2.5297 - val_accuracy: 0.1256
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5299 - accuracy: 0.1436 - val_loss: 2.5354 - val_accuracy: 0.1314
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5150 - accuracy: 0.1468 - val_loss: 2.5368 - val_accuracy: 0.1358
# Epoch 9/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5026 - accuracy: 0.1537 - val_loss: 2.5314 - val_accuracy: 0.1371
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4908 - accuracy: 0.1534 - val_loss: 2.5243 - val_accuracy: 0.1435
# The learning rate is 3.689836642813878e-07
# The end of 13 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 93ms/step - loss: 2.6184 - accuracy: 0.1018 - val_loss: 2.4813 - val_accuracy: 0.0861
# Epoch 2/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6004 - accuracy: 0.1053 - val_loss: 2.4882 - val_accuracy: 0.0759
# Epoch 3/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5868 - accuracy: 0.1065 - val_loss: 2.5055 - val_accuracy: 0.0829
# Epoch 4/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5717 - accuracy: 0.1091 - val_loss: 2.5250 - val_accuracy: 0.0746
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5604 - accuracy: 0.1087 - val_loss: 2.5375 - val_accuracy: 0.0842
# Epoch 6/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5490 - accuracy: 0.1087 - val_loss: 2.5426 - val_accuracy: 0.0963
# Epoch 7/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5401 - accuracy: 0.1122 - val_loss: 2.5466 - val_accuracy: 0.1014
# Epoch 8/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5271 - accuracy: 0.1122 - val_loss: 2.5457 - val_accuracy: 0.1052
# Epoch 9/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5206 - accuracy: 0.1144 - val_loss: 2.5432 - val_accuracy: 0.1065
# Epoch 10/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5116 - accuracy: 0.1191 - val_loss: 2.5375 - val_accuracy: 0.1078
# The learning rate is 3.690193200125211e-07
# The end of 14 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 91ms/step - loss: 2.8403 - accuracy: 0.0578 - val_loss: 2.4901 - val_accuracy: 0.0810
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6337 - accuracy: 0.0833 - val_loss: 2.4929 - val_accuracy: 0.0810
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5304 - accuracy: 0.1150 - val_loss: 2.4819 - val_accuracy: 0.0886
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4723 - accuracy: 0.1402 - val_loss: 2.4608 - val_accuracy: 0.1142
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4250 - accuracy: 0.1615 - val_loss: 2.4386 - val_accuracy: 0.1307
# Epoch 6/10
# 100/100 [==============================] - 9s 92ms/step - loss: 2.3903 - accuracy: 0.1766 - val_loss: 2.4143 - val_accuracy: 0.1499
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3588 - accuracy: 0.1842 - val_loss: 2.3919 - val_accuracy: 0.1626
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.3301 - accuracy: 0.2049 - val_loss: 2.3717 - val_accuracy: 0.1735
# Epoch 9/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3038 - accuracy: 0.2115 - val_loss: 2.3514 - val_accuracy: 0.1894
# Epoch 10/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.2762 - accuracy: 0.2260 - val_loss: 2.3314 - val_accuracy: 0.1983
# The learning rate is 2.6879986942310635e-06
# The end of 15 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 92ms/step - loss: 2.6896 - accuracy: 0.0723 - val_loss: 2.4928 - val_accuracy: 0.1084
# Epoch 2/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6776 - accuracy: 0.0757 - val_loss: 2.5204 - val_accuracy: 0.1097
# Epoch 3/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6657 - accuracy: 0.0757 - val_loss: 2.5491 - val_accuracy: 0.0989
# Epoch 4/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6539 - accuracy: 0.0795 - val_loss: 2.5610 - val_accuracy: 0.0938
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6436 - accuracy: 0.0839 - val_loss: 2.5686 - val_accuracy: 0.0925
# Epoch 6/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6334 - accuracy: 0.0871 - val_loss: 2.5907 - val_accuracy: 0.0899
# Epoch 7/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6266 - accuracy: 0.0845 - val_loss: 2.6135 - val_accuracy: 0.0823
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6153 - accuracy: 0.0883 - val_loss: 2.6230 - val_accuracy: 0.0816
# Epoch 9/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6064 - accuracy: 0.0937 - val_loss: 2.6239 - val_accuracy: 0.0797
# Epoch 10/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.6009 - accuracy: 0.0962 - val_loss: 2.6192 - val_accuracy: 0.0816
# The learning rate is 1.6377586277036117e-07
# The end of 16 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 92ms/step - loss: 2.4030 - accuracy: 0.1867 - val_loss: 2.4700 - val_accuracy: 0.1518
# Epoch 2/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.0545 - accuracy: 0.3303 - val_loss: 2.4991 - val_accuracy: 0.1869
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.7332 - accuracy: 0.4679 - val_loss: 2.4898 - val_accuracy: 0.2245
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.3907 - accuracy: 0.5717 - val_loss: 2.1446 - val_accuracy: 0.2557
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 1.1128 - accuracy: 0.6622 - val_loss: 1.6976 - val_accuracy: 0.4241
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.9087 - accuracy: 0.7307 - val_loss: 1.3643 - val_accuracy: 0.5344
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.7678 - accuracy: 0.7712 - val_loss: 1.2286 - val_accuracy: 0.5835
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.6531 - accuracy: 0.8212 - val_loss: 1.1206 - val_accuracy: 0.6186
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 0.5710 - accuracy: 0.8517 - val_loss: 1.0642 - val_accuracy: 0.6403
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 0.5005 - accuracy: 0.8815 - val_loss: 1.0552 - val_accuracy: 0.6435
# The learning rate is 4.8952260796924924e-05
# The end of 17 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 93ms/step - loss: 2.6821 - accuracy: 0.0710 - val_loss: 2.4939 - val_accuracy: 0.0631
# Epoch 2/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.6135 - accuracy: 0.0820 - val_loss: 2.4876 - val_accuracy: 0.0810
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5653 - accuracy: 0.0977 - val_loss: 2.4730 - val_accuracy: 0.0982
# Epoch 4/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5284 - accuracy: 0.1087 - val_loss: 2.4668 - val_accuracy: 0.1129
# Epoch 5/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5007 - accuracy: 0.1238 - val_loss: 2.4699 - val_accuracy: 0.1231
# Epoch 6/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4805 - accuracy: 0.1380 - val_loss: 2.4749 - val_accuracy: 0.1218
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4616 - accuracy: 0.1370 - val_loss: 2.4753 - val_accuracy: 0.1282
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4476 - accuracy: 0.1486 - val_loss: 2.4707 - val_accuracy: 0.1346
# Epoch 9/10
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4347 - accuracy: 0.1552 - val_loss: 2.4641 - val_accuracy: 0.1409
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4227 - accuracy: 0.1590 - val_loss: 2.4564 - val_accuracy: 0.1416
# The learning rate is 1.1775029824064013e-06
# The end of 18 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 92ms/step - loss: 2.6134 - accuracy: 0.0984 - val_loss: 2.4732 - val_accuracy: 0.1001
# Epoch 2/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5699 - accuracy: 0.1050 - val_loss: 2.4837 - val_accuracy: 0.1033
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5358 - accuracy: 0.1160 - val_loss: 2.4944 - val_accuracy: 0.1020
# Epoch 4/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5113 - accuracy: 0.1270 - val_loss: 2.4874 - val_accuracy: 0.1071
# Epoch 5/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.4848 - accuracy: 0.1329 - val_loss: 2.4744 - val_accuracy: 0.1199
# Epoch 6/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4693 - accuracy: 0.1458 - val_loss: 2.4652 - val_accuracy: 0.1429
# Epoch 7/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4484 - accuracy: 0.1502 - val_loss: 2.4601 - val_accuracy: 0.1460
# Epoch 8/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4331 - accuracy: 0.1556 - val_loss: 2.4537 - val_accuracy: 0.1492
# Epoch 9/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4182 - accuracy: 0.1571 - val_loss: 2.4458 - val_accuracy: 0.1550
# Epoch 10/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4026 - accuracy: 0.1647 - val_loss: 2.4364 - val_accuracy: 0.1582
# The learning rate is 8.197519730108344e-07
# The end of 19 iteration
# Epoch 1/10
# 100/100 [==============================] - 10s 93ms/step - loss: 2.5631 - accuracy: 0.1103 - val_loss: 2.4683 - val_accuracy: 0.1231
# Epoch 2/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.5100 - accuracy: 0.1298 - val_loss: 2.4566 - val_accuracy: 0.1167
# Epoch 3/10
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4717 - accuracy: 0.1439 - val_loss: 2.4482 - val_accuracy: 0.1180
# Epoch 4/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.4407 - accuracy: 0.1515 - val_loss: 2.4347 - val_accuracy: 0.1244
# Epoch 5/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.4118 - accuracy: 0.1609 - val_loss: 2.4166 - val_accuracy: 0.1467
# Epoch 6/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3871 - accuracy: 0.1750 - val_loss: 2.3982 - val_accuracy: 0.1639
# Epoch 7/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3644 - accuracy: 0.1842 - val_loss: 2.3838 - val_accuracy: 0.1696
# Epoch 8/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3427 - accuracy: 0.1958 - val_loss: 2.3703 - val_accuracy: 0.1773
# Epoch 9/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3219 - accuracy: 0.2011 - val_loss: 2.3566 - val_accuracy: 0.1824
# Epoch 10/10
# 100/100 [==============================] - 9s 91ms/step - loss: 2.3037 - accuracy: 0.2099 - val_loss: 2.3427 - val_accuracy: 0.1913
# The learning rate is 1.581418478598204e-06
# The end of 20 iteration

# %% [markdown]
# We got the highest accuracy at a learning rate of 9.092371837156582e-05. Let's go ahead with that

# %%
from tensorflow import keras

# %% [markdown]
# We will now define a callback for early stopping

# %%
import tensorflow
callback = tensorflow.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4, min_delta=0.01)

# %%
epochs=30
lr = 9.092371837156582e-05

model = Sequential()

model.add(Conv2D(filters=8,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(Conv2D(filters=16,kernel_size=3,activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(12,activation='softmax'))

optimizer = optimizers.Adam(learning_rate = lr)

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x=X_train, y=y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test),callbacks=[callback])
# Out:
# Epoch 1/30
# 100/100 [==============================] - 10s 94ms/step - loss: 2.2413 - accuracy: 0.2263 - val_loss: 2.4728 - val_accuracy: 0.1212
# Epoch 2/30
# 100/100 [==============================] - 9s 90ms/step - loss: 1.7863 - accuracy: 0.4023 - val_loss: 2.7569 - val_accuracy: 0.1205
# Epoch 3/30
# 100/100 [==============================] - 9s 91ms/step - loss: 1.4558 - accuracy: 0.5302 - val_loss: 2.9426 - val_accuracy: 0.1327
# Epoch 4/30
# 100/100 [==============================] - 9s 93ms/step - loss: 1.1499 - accuracy: 0.6505 - val_loss: 2.3981 - val_accuracy: 0.2417
# Epoch 5/30
# 100/100 [==============================] - 9s 92ms/step - loss: 0.9123 - accuracy: 0.7335 - val_loss: 2.2916 - val_accuracy: 0.3093
# Epoch 6/30
# 100/100 [==============================] - 9s 93ms/step - loss: 0.7452 - accuracy: 0.7901 - val_loss: 1.5230 - val_accuracy: 0.4656
# Epoch 7/30
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6025 - accuracy: 0.8441 - val_loss: 1.2001 - val_accuracy: 0.5848
# Epoch 8/30
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5052 - accuracy: 0.8699 - val_loss: 1.1547 - val_accuracy: 0.5963
# Epoch 9/30
# 100/100 [==============================] - 9s 93ms/step - loss: 0.4295 - accuracy: 0.8947 - val_loss: 1.0960 - val_accuracy: 0.6371
# Epoch 10/30
# 100/100 [==============================] - 9s 93ms/step - loss: 0.3626 - accuracy: 0.9189 - val_loss: 0.9980 - val_accuracy: 0.6728
# Epoch 11/30
# 100/100 [==============================] - 9s 94ms/step - loss: 0.3017 - accuracy: 0.9349 - val_loss: 0.9978 - val_accuracy: 0.6716
# Epoch 12/30
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2585 - accuracy: 0.9425 - val_loss: 1.0059 - val_accuracy: 0.6639
# Epoch 13/30
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2289 - accuracy: 0.9544 - val_loss: 0.9953 - val_accuracy: 0.6684
# Epoch 14/30
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2036 - accuracy: 0.9629 - val_loss: 1.0086 - val_accuracy: 0.6773

# %% [markdown]
# The accuracy is around 68% which is the highest among the three methods we have done so far

# %% [markdown]
# # Result Comparison

# %% [markdown]
# We have tried three approaches. We have tried
#
# - Supervised Learning Algorithms
# - Neural Networks
# - Convolutional Neural Networks

# %% [markdown]
# Among Supervised techniques, XGboost outperformed the rest and gave a validation accuracy of around 55%.

# %% [markdown]
# Neural Networks gave a validation accuracy of around 45%.

# %% [markdown]
# CNN's outperformed the rest. They gave a validation accuracy of around 68%. It is expected that CNN's will outperform the rest due to convolutions. The convolutions extract features from the data. The earlier convolutions extract broader features while the latter ones extract more specific features. These convolutions are akin to the feature engineering steps we do as part of Machine Learning and hence improve the accuracy of the model. The regular Neural Networks don't include this and hence we cannot expect them to perform on par with CNN's.

# %% [markdown]
# # Pickle the best performing model

# %% [markdown]
# We will now pickle the best performing model which is CNN

# %%
model.save('/content/drive/My Drive/Computer Vision/cnn_model.pkl')
model.save_weights('/content/drive/My Drive/Computer Vision/cnn_model_weights.pkl')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Computer Vision/cnn_model.pkl/assets

# %% [markdown]
# # Import the the test image to predict the class. Display the image. Use the best trained image classifier model to predict the class.

# %% [markdown]
# Let's load the pretrained model and model weights

# %%
from tensorflow.keras.models import load_model

pretrained_model = load_model('/content/drive/My Drive/Computer Vision/cnn_model.pkl')
pretrained_model.load_weights('/content/drive/My Drive/Computer Vision/cnn_model_weights.pkl')

# %% [markdown]
# Let's test model on a single image

# %%
tests = datagen.flow_from_directory('/content/drive/My Drive/Computer Vision',target_size=(64,64),classes=['Seedling - Prediction'])
# Out:
# Found 1 images belonging to 1 classes.

# %%
X_t,y_t = next(tests)

# %%
X_t.shape
# Out:
# (1, 64, 64, 3)

# %% [markdown]
# Let's now visualize the test image below

# %%
plt.imshow(X_t.reshape(64,64,3));

# %% [markdown]
# Let's now predict the test image

# %%
np.argmax(pretrained_model.predict(X_t))
# Out:
# 7

# %% [markdown]
# We have predicted the test image to be 7. Let's look at the dictionary to see what 7 is

# %%
data.class_indices
# Out:
# {'Black-grass': 0,
#  'Charlock': 1,
#  'Cleavers': 2,
#  'Common Chickweed': 3,
#  'Common wheat': 4,
#  'Fat Hen': 5,
#  'Loose Silky-bent': 6,
#  'Maize': 7,
#  'Scentless Mayweed': 8,
#  'Shepherds Purse': 9,
#  'Small-flowered Cranesbill': 10,
#  'Sugar beet': 11}

# %% [markdown]
# We can see that 7 corresponds to Maize. We have predicted the test image to be Maize
